# %% [markdown]
# 3. 모든 직원의 이름과 연봉 정보만을 조회하는 쿼리를 작성해주세요
# ![day03_assignment01.png](data:image/png;base64,...)

# %% [markdown]
# 4.Frontend 직책을 가진 직원 중에서 연봉이 90000 이하인 직원의 이름과 연봉을 조회하세요.
#
# ![day03_assignment02.png](data:image/png;base64,...)

# %% [markdown]
# 5.PM 직책을 가진 모든 직원의 연봉을 10% 인상한 후 그 결과를 확인하세요.
#
# ![day03_assignment03.png](data:image/png;base64,...)

# %% [markdown]
# 6. 모든 Backend' 직책을 가진 직원의 연봉을 5% 인상하세요.
#
# ![day03_assignment04.png](data:image/png;base64,...)

# %% [markdown]
# 7. 민혁 사원의 데이터를 삭제하세요
#
# ![day03_assignment05.png](data:image/png;base64,...)

# %% [markdown]
# 8. 모든 직원을 position 별로 그룹화하여 각 직책의 평균 연봉을 계산하세요.
#
# ![day03_assignment06.png](data:image/png;base64,...)

# %% [markdown]
# 9. employees 테이블을 삭제하세요.
#
#
# ![day03_assignment07.png](data:image/png;base64,...)

# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```비교 연산자의 결과로 올바르지 않은 것을 골라주세요```
#
# 1. 8 == 2 * 4&emsp;&emsp;결과 : True
# 2. 4 != 2 + 2&emsp;&emsp;결과 : False
# 3. 2 * 3 is 3 + 3&emsp;&emsp;결과 : True
# 4. 8 is 4 * 2.0&emsp;&emsp;결과 : True
# 5. 5 is 6 - 1.1&emsp;&emsp;결과 : False

# %% [markdown]
# <span style="color:red">답변</span>

# %%
a = 8 == 2 * 4
print(a)
b = 4 != 2 + 2
print(b)
c = 2 * 3 is 3 + 3
print(c)
d = 8 is 4 * 2.0
print(d)
e = 5 is 6 - 1.1
print(e)
# Out:
# True
# False
# True
# False
# False
# <>:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-2-1cbaf1e22233>:5: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   c = 2 * 3 is 3 + 3
# <ipython-input-2-1cbaf1e22233>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   d = 8 is 4 * 2.0
# <ipython-input-2-1cbaf1e22233>:9: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   e = 5 is 6 - 1.1

# %% [markdown]
# 4번

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```"x는 5와 같지 않다"라는 뜻과 동일한 것을 골라주세요```
#
# 1. x <= 5
# 2. x != 5
# 3. x & 5
# 4. x ! 5

# %% [markdown]
# <span style="color:red">답변</span>

# %%
a = 5
b = 5
print(a != b)
print(a is b)
# Out:
# False
# True

# %%
2번

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```비교 연산자와 논리 연산자의 결과로 올바른 것을 모두 골라주세요```
#
# x = 10
# y = 20
#
# 1. x == 10 or y == 10  결과 : False
# 2. x >= 10 and y < 30  결과 : True
# 3. not x == 10 결과 : False
# 4. y != 20 or x != 10  결과 : True
# 5. not y != 20 and x > 5  결과 : False

# %% [markdown]
# <span style="color:red">답변</span>

# %%
x=10
y=20
a = x == 10 or y == 10
print(a)
b = x >= 10 and y < 30
print(b)
c = not x == 10
print(c)
d = y != 20 or x != 10
print(d)
e = not y != 20 and x > 5
print(e)
# Out:
# True
# True
# False
# False
# True

# %% [markdown]
# 2번

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```'치맥' and True의 결과로 올바른 것을 골라주세요```
#
# 1. False
# 2. 아묻따
# 3. True
# 4. 치맥True

# %% [markdown]
# <span style="color:red">답변</span>

# %%
"치맥" and True
# Out:
# True

# %% [markdown]
# 3번

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```논리 연산의 결과를 뒤집는 연산자를 골라주세요```
#
# 1. is not
# 2. not
# 3. !=
# 4. end
# 5. and
# 6. or

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3번

# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# tuple과 list의 차이점으로 올바른 것을 모두 골라주세요
#
# 1. list만인덱싱이 가능해 원하는 값을 인덱스로 추출할 수 있다.
# 2. tuple은 불편이고 list는 가변이다.
# 3. tuple은 소괄호( () )를 사용하고 리스트는 대괄호( [ ] )를 사용한다.
# 4. 튜플은 입출력이 자주 발행하는 경우 사용하고 리스트는 입출력이 자주 발생하지 않는 상황에 사용한다

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2번 오타인가요? 불변이면 정답입니다.
# 3번

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# tuple a에 사용할 수 없는 코드를 골라주세요<br>
# a = (20, 10, 15)
#
# 1. print(a[:])
# 2. a.pop()
# 3. sum(a)
# 4. a.count(20)

# %%
a = (20, 10, 15)
a.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-381eacd1f115> in <cell line: 2>()
#       1 a = (20, 10, 15)
# ----> 2 a.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 2번

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# 아래 코드를 실행시켰을 때 발생하는 상황과 원인을 간략히 설명해주세요
#
# ```
# 바구니 = ( "상추", "깻잎", "삼겹살")
# 바구니[1] = "고사리"
# ```

# %% [markdown]
# <span style="color:red">답변</span>

# %%
바구니 = ( "상추", "깻잎", "삼겹살")
바구니[1] = "고사리"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-ca6052b4b176> in <cell line: 2>()
#       1 바구니 = ( "상추", "깻잎", "삼겹살")
# ----> 2 바구니[1] = "고사리"
#
# TypeError: 'tuple' object does not support item assignment

# %%
바구니 = [ "상추", "깻잎", "삼겹살"]
바구니[1] = "고사리"
print(바구니)
# Out:
# ['상추', '고사리', '삼겹살']

# %% [markdown]
# 선언할때 튜플은 불변하기 때문에 에러가 발생한다.
# 아래와 같이 리스트로 바꾸면 에러가 나지 않는다.

# %% [markdown]
# ----

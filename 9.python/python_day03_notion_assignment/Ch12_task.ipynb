# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# 딕셔너리 x에서 키에 해당하는 값을 모두 삭제하는 방법으로 옳은 것을 모두 골라주세요
#
# x = {'banana':3000, 'apple':1500, 'orange':2000}
#
# 1. x.pop('apple')
# 2. x.remove('python')
# 3. del x['orange']
# 4. x.popitem()

# %% [markdown]
# <span style="color:red">답변</span>

# %%
x = {'banana':3000, 'apple':1500, 'orange':2000}
x.pop('apple')
print(x)
# Out:
# {'banana': 3000, 'orange': 2000}

# %% [markdown]
# 1번

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# 딕셔너리의 메서드에 대한 설명으로 올바르지 않은 것을 모두 고르세요<br>
#
# 1. setdefault는 키만 지정하면 값은 0으로 저장한다.
# 2. update는 딕셔너리에서 키의 값을 수정한다.
# 3. keys는 딕셔너리의 키-값 쌍을 모두 가져온다.
# 4. clear는 딕셔너리의 모든 키-값 쌍을 삭제한다.
# 5. setdefault에 키와 값을 넣어 실행하면 기존 딕셔너리에 없는 키값일 경우 키-값 쌍을 추가한다.

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 1번 value 값을 none으로 지정된다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# 평균 점수를 구하는 코드를 result 변수에 작성해주세요
#
# ```
# ozkim = { "국어" : 90, "'수학" : 80, "과학" : 82, "영어" : 72 }
# result =
# print(result)
# ```

# %% [markdown]
# <span style="color:red">답변</span>

# %%
ozkim = { "국어" : 90, "'수학" : 80, "과학" : 82, "영어" : 72 }
result = (ozkim["국어"]+ozkim["'수학"]+ozkim["과학"]+ozkim["영어"])/4
print(result)
# Out:
# 81.0

# %% [markdown]
# (ozkim["국어"]+ozkim["'수학"]+ozkim["과학"]+ozkim["영어"])/4

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# 상자 딕셔너리에 아래 데이터를 추가하는 코드를 작성해 주세요
#
# ```
# 상자 = {"아디다스": ["신발", "2개"],
#             "나이키": ["모자", "5개"],
#             "뉴발란스": ["가방", "1개"]}
# ````
#
# 입력할 데이터 : 칼하트 / 후드티 / 2벌

# %% [markdown]
# <span style="color:red">답변</span>

# %%
상자 = {"아디다스": ["신발", "2개"],
            "나이키": ["모자", "5개"],
            "뉴발란스": ["가방", "1개"]
            }
상자["칼하트"] = ["후드티", "2벌"]
print(상자)
# Out:
# {'아디다스': ['신발', '2개'], '나이키': ['모자', '5개'], '뉴발란스': ['가방', '1개'], '칼하트': ['후드티', '2벌']}

# %% [markdown]
# 상자 = {"아디다스": ["신발", "2개"],
#             "나이키": ["모자", "5개"],
#             "뉴발란스": ["가방", "1개"]
#             }
# 상자["칼하트"] = ["후드티", "2벌"]
# print(상자)

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# 아래 keys 변수와 vals 변수에 들어있는 값을 이용해 result라는 딕셔너리를 만드는 코드를 작성해주세요
#
# ```
# keys = ["뉴진스", "아이브", "에스파"]
# vals = ["하이브" , "스타쉽", "SM"]
# ```

# %%
keys = ["뉴진스", "아이브", "에스파"]
vals = ["하이브" , "스타쉽", "SM"]
result = dict(zip(keys, vals))
print(result)
# Out:
# {'뉴진스': '하이브', '아이브': '스타쉽', '에스파': 'SM'}

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# keys = ["뉴진스", "아이브", "에스파"]
# vals = ["하이브" , "스타쉽", "SM"]
# result = dict(zip(keys, vals))
# print(result)

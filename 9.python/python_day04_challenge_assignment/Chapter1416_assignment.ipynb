# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter14 ~ 16 수업은 잘 들으셨나요?
#
# Chapter14 ~ 16의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후 ▷ 버튼을 클릭해 코드를 실행해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# [문제1]
#
# 주어진 정수 x와 자연수 n을 이용해, x부터 시작해 x씩 증가하는 숫자를 n개 지니는 리스트를 출력해주세요
#
# x = 2, n =5

# %%
x = 2
n = 5
while x < 10:
    print(x, n)
    x += 2
    n -= 1
    if n == 0:
        break
arr = [x, n]
print(*arr)
# Out:
# 2 5
# 4 4
# 6 3
# 8 2
# 10 1

# %% [markdown]
# ---

# %% [markdown]
# [문제2]
#
# 전화번호가 문자열 phone_number로 주어졌을 때, 전화번호의 뒷 4자리를 *으로 가린 문자열이 출력되도록 코드를 작성해주세요
#
# phone_number = "01012347890"
#
# 출력 예시 : "0101234****"

# %%
phone_number = "01012347890"
print(phone_number.replace(phone_number[7:11], "****"))
# Out:
# 0101234****

# %% [markdown]
# ---

# %% [markdown]
# [문제3]
#
# 숫자를 건넬 때 일부 자릿수를 영단어로 바꾼 카드를 건네주면 프로도는 원래 숫자를 찾는 게임입니다.
#
# 다음은 숫자의 일부 자릿수를 영단어로 바꾸는 예시입니다.
#
# 1478 → "one4seveneight"
# 234567 → "23four5six7"
# 10203 → "1zerotwozero3"
#
# 이렇게 숫자의 일부 자릿수가 영단어로 바뀌어졌거나,
# 혹은 바뀌지 않고 그대로인 문자열 s가 주어졌을때
# s가 의미하는 원래 숫자를 출력하도록 코드를 작성해주세요
#
# s = "77three4one
#
# ---
# 참고로 각 숫자에 대응되는 영단어는 다음 표와 같습니다.
#
# 숫자	영단어
# 0	zero
# 1	one
# 2	two
# 3	three
# 4	four
# 5	five
# 6	six
# 7	seven
# 8	eight
# 9	nine

# %%
s = "77three4one"
s = s.replace("one", "1")
s = s.replace("two", "2")
s = s.replace("three", "3")
s
# Out:
# '77341'

# %% [markdown]
# ---

# %% [markdown]
# [문제4]
#
# 행렬의 덧셈은 행과 열의 크기가 같은 두 행렬의 같은 행, 같은 열의 값을 서로 더한 결과가 됩니다. 2개의 행렬 arr1과 arr2가 주어졌을 때, 행렬 덧셈의 결과를 출력하는 코드를 작성해주세요(result와 같은 결과가 출력되도록 작성)
#
# arr1 = [[1,2],[2,3]]
#
# arr2 = [[3,4],[5,6]]
#
# result = [[4,6],[7,9]]

# %%
arr1= [[1,2],[2,3]]
arr2 = [[3,4],[5,6]]
result = [[0,0],[0,0]]
for i in range(len(arr1)):
    for j in range(len(arr1[0])):
        result[i][j] = arr1[i][j] + arr2[i][j]
print(result)
# Out:
# [[4, 6], [7, 9]]

# %% [markdown]
# ---

# %% [markdown]
# [문제5]
#
# 양의 정수 x가 하샤드 수이려면 x의 자릿수의 합으로 x가 나누어져야 합니다.
# 예를 들어 18의 자릿수 합은 1+8=9이고, 18은 9로 나누어 떨어지므로 18은 하샤드 수입니다.
# 주어진 x를 이용해 x가 하샤드 수인지 아닌지 검사하는 코드를 작성해주세요
#
# x = 17
#
# ----
#
# 입출력 예시
# x	결과값
# 10	true
# 12	true
# 11	false
# 13	false

# %%
x = 17
sum = 0
for i in str(x):
    sum += int(i)
if x % sum == 0:
    print("true")
else:
    print("false")
# Out:
# false

# %% [markdown]
# ---

# %% [markdown]
# [문제6]
#
# String형 배열 seoul의 element중 "Kim"의 인덱스 x를 찾아, "김서방은 x에 있다"는 String을 출력하는 코드를 작성해주세요.
#
# seoul에 "Kim"은 오직 한 번만 나타나며 잘못된 값이 입력되는 경우는 없습니다.
#
# seoul = ["Jane", "Kim"]
#
# 결과
# "김서방은 1에 있다"

# %%
seoul = ["Jane", "Kim"]
for i in range(len(seoul)):
    if seoul[i] == "Kim":
        print(f"김서방은 {i}에 있다")
# Out:
# 김서방은 1에 있다

# %% [markdown]
# ---

# %% [markdown]
# [문제7]
#
# 0부터 9까지의 숫자 중 일부가 들어있는 정수 배열 numbers가 주어집니다.
# numbers에서 찾을 수 없는 0부터 9까지의 숫자를 모두 찾아 더한 수를 출력해주세요
#
# numbers = [5,8,1,0,6,9]

# %%
numbers = [5,8,1,0,6,9]
sum = 0
for i in range(10):
    if i not in numbers:
        sum += i
print(sum)
# Out:
# 16

# %% [markdown]
# #### 프로젝트: 붕어빵 자동 판매 시스템
#
#
# 당신은 붕어빵 가게의 주인입니다.
#
# 손님들이 붕어빵을 주문하면 이를 자동으로 처리하고, 재고를 관리하는 시스템을 만들고자 합니다. 또한, 관리자 모드를 통해 재고를 추가할 수 있는 기능을 구현해야 합니다.

# %% [markdown]
# [문제 1: 붕어빵 재고 확인]
#
# 붕어빵 가게의 현재 재고를 확인하는 기능을 구현하세요.
#
# 요구사항:
# - 현재 붕어빵의 재고를 딕셔너리로 관리합니다.
# - 딕셔너리에는 붕어빵의 종류와 각각의 재고 개수가 저장됩니다.
# - 현재 재고를 화면에 출력하세요.
#
# 붕어빵 재고
# - 팥붕어빵 : 10개
# - 슈크림붕어빵 : 8개
# - 초코붕어빵 : 5개

# %%
팥붕어빵 = 10
슈크림붕어빵 = 8
초코붕어빵 = 5
재고 = {"팥붕어빵": 팥붕어빵, "슈크림붕어빵": 슈크림붕어빵, "초코붕어빵": 초코붕어빵}
재고
# Out:
# {'팥붕어빵': 10, '슈크림붕어빵': 8, '초코붕어빵': 5}

# %%
list_재고 = list(재고.values())
list_재고
# Out:
# [10, 8, 5]

# %% [markdown]
# [문제 2: 붕어빵 주문 받기]
#
# 손님이 주문한 붕어빵의 종류와 개수를 입력받는 기능을 구현하세요.
#
# 요구사항:
# - 손님이 주문할 붕어빵의 종류와 개수를 입력받습니다.
# - 주문 내용을 딕셔너리에 저장하세요.
# - 주문 내역을 출력해주세요.

# %%
손님주문 = {}
print("팥붕어빵 주문개수를 입력하세요")
손님주문['팥붕어빵'] = int(input())
print("슈크림붕어빵 주문개수를 입력하세요")
손님주문['슈크림붕어빵'] = int(input())
print("초코붕어빵 주문개수를 입력하세요")
손님주문['초코붕어빵'] = int(input())


손님주문
# Out:
# 팥붕어빵 주문개수를 입력하세요
# 3
# 슈크림붕어빵 주문개수를 입력하세요
# 2
# 초코붕어빵 주문개수를 입력하세요
# 1
# {'팥붕어빵': 3, '슈크림붕어빵': 2, '초코붕어빵': 1}

# %%
list_손님주문 = list(손님주문.values())
list_손님주문
# Out:
# [11, 2, 33]

# %% [markdown]
# [문제 3: 붕어빵 주문 처리]
#
# 손님의 주문을 처리하여 붕어빵 재고를 업데이트하는 기능을 구현하세요.
#
# 요구사항:
# - 손님의 주문 내용을 기반으로 재고를 업데이트합니다.
# - 재고가 부족할 경우, 손님에게 재고 부족을 알리고 재고를 감소시키지 않습니다.
# - 재고가 충분할 경우, 주문한 만큼 재고를 감소시키고 판매를 완료합니다.
# - 판매가 완료된 경우 판매된 붕어빵 맛과 개수를 출력하세요.

# %%
#팥붕어빵재고= list_재고[0] - list_손님주문[0]
#슈크림붕어빵재고 = list_재고[1] - list_손님주문[1]
#초코붕어빵재고 = list_재고[2] - list_손님주문[2]
#print("팔고남은 팥붕어빵은", 팥붕어빵재고, "개 입니다.")
#print("팔고남은 슈크림붕어빵은", 슈크림붕어빵재고, "개 입니다.")
#print("팔고남은 초코붕어빵은", 초코붕어빵재고, "개 입니다.")

if 팥붕어빵재고 > 0:
  팥붕어빵재고= list_재고[0] - list_손님주문[0]
  print("팔고남은 팥붕어빵은", 팥붕어빵재고, "개 입니다.")
else:
  print("팥붕어빵 재고가 부족합니다.")
  print("남은 팥붕어빵은", list_재고[0],"개입니다")
if 슈크림붕어빵재고 > 0:
  슈크림붕어빵재고 = list_재고[1] - list_손님주문[1]
  print("팔고남은 슈크림붕어빵은", 슈크림붕어빵재고, "개 입니다.")
else:
  print("슈크림붕어빵 재고가 부족합니다.")
  print("남은 슈크림붕어빵은", list_재고[1],"개입니다")
if 초코붕어빵재고 > 0:
  초코붕어빵재고 = list_재고[2] - list_손님주문[2]
else:
  print("초코붕어빵 재고가 부족합니다.")
  print("남은 초코붕어빵은", list_재고[2],"개입니다")
# Out:
# 팥붕어빵 재고가 부족합니다.
# 남은 팥붕어빵은 10 개입니다
# 팔고남은 슈크림붕어빵은 6 개 입니다.
# 초코붕어빵 재고가 부족합니다.
# 남은 초코붕어빵은 5 개입니다

# %% [markdown]
# [문제 4: 여러 손님 주문 처리]
#
# 여러 손님들의 주문을 처리할 수 있도록 시스템을 확장하세요.
#
# 요구사항:
# - 손님이 "종료"를 입력할 때까지 주문을 계속 받습니다.
# - 각 주문마다 재고를 업데이트합니다.
# - 현재 재고를 화면에 출력합니다.

# %% [markdown]
# [문제 5: 관리자 모드]
#
# 관리자 모드를 통해 붕어빵 재고를 추가할 수 있는 기능을 구현하세요.
#
# 요구사항:
# - 관리자는 특정 붕어빵의 재고를 추가할 수 있습니다.
# - "종료"를 입력하면 관리자 모드를 종료합니다.
# - 추가된 재고를 업데이트하고 현재 재고를 화면에 출력합니다.

# %% [markdown]
# [문제 6: 매출 확인]
#
# 붕어빵 판매 가격을 설정하고, 판매한 붕어빵의 매출을 계산하세요.
#
# 요구사항:
# - 각 붕어빵의 가격을 딕셔너리로 관리합니다.
# - 판매된 붕어빵의 종류와 개수를 딕셔너리로 관리합니다.
# - 총 매출을 계산하여 출력합니다.
#
# 초기 설정:
# - 가격
#     - "팥붕어빵": 1000
#     - "슈크림붕어빵": 1200
#     - "초코붕어빵": 1500
#
# - 판매 개수
#     - "팥붕어빵": 0
#     - "슈크림붕어빵": 0
#     - "초코붕어빵": 0

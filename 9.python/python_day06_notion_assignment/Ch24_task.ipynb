# %% [markdown]
# 사용자의 이름, 나이, 성별을 출력하는 함수 print_info를 작성하세요. 이 때, 모든 매개변수는 키워드 매개변수로만 받도록 하세요.

# %%
def print_info(**info):
    print("이름:","손흠민")
    print("나이:",32)
    print("성별:","남자")
print_info()
# Out:
# 이름: 손흠민
# 나이: 32
# 성별: 남자

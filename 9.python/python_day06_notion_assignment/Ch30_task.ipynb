# %% [markdown]
# 팩토리얼을 계산하는 재귀 함수 factorial을 작성하세요.

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)

n = int(input("숫자를 입력하세요: "))
print(factorial(n))
# Out:
# 숫자를 입력하세요: 4
# 24
